# %% [markdown]
# <h4>Task 1: Simple Linear Regression with Scikit-Learn
# Objective:
# In this exercise, we will learn the basics of linear regression, a fundamental machine
# learning technique, by building a simple linear regression model using Scikit-Learn. We will
# also visualize the results to understand how the model fits the data.
# Dataset:
# We will use a synthetic dataset for this exercise, where we predict the price of a house based on
# its size (in square feet).</h4>

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Step1: Creating a Synthentic dataset

# %%
# Generating a random house sizes between 500, 2500
np.random.seed(0)  #For reproducibility
house_sizes = np.random.randint(500, 2500, size=100)
house_sizes
# Out:
# array([1184, 1059, 2153, 1716, 1335, 1263, 2231, 1883, 1533, 2247,  777,
#        2278, 2328, 1099, 1594, 1996, 1100, 1920,  814, 1205, 2010, 1051,
#         587,  674, 2124, 1349, 2201, 1037, 1345,  572, 1277, 2440,  615,
#        1476, 1255, 2233, 2371, 1955,  948, 1350,  599, 1701, 1255, 1297,
#        1159, 1671, 1410,  923, 1812, 2485, 1789, 1197, 1139, 1044, 1043,
#        1214,  744,  651, 1175, 1010, 1983, 1382, 1707,  528, 1302,  628,
#         628, 2456, 1577, 2425, 2074, 2012, 1256,  773,  835,  888, 2141,
#        1566, 1966, 1043, 1388,  757, 1845, 2461,  557,  791, 2394, 1643,
#        1279,  930, 1606,  591, 2420,  898, 1111, 2089, 1408, 1133, 2462,
#         584])

# %%
#  Generating house prices based on sizes with some noise
# Price = 50* house_sizes + some random noise
house_prices = 50* house_sizes + np.random.normal(0, 10000, size=100)
house_prices
# Out:
# array([ 63253.97784018,  54136.06585234, 120194.14068338,  99991.02040789,
#         59311.4391713 ,  37975.62897205,  96479.03976465, 105640.76125382,
#         64714.21748056, 123760.42445843,  53944.45082265, 124577.75129464,
#        109534.10522807,  55098.73316058,  75943.34103835,  99417.76362555,
#         58679.7447415 ,  95552.76299752,  37676.24867481,  38005.96397788,
#        107740.06359042,  56140.0276447 ,  40111.21037519,  35621.40834386,
#        114729.25957501,  67633.5718261 , 114333.03566508,  61812.77834548,
#         62338.50344099,  35726.78165743,  74983.40349621, 100463.25413642,
#         26588.88517567,  63091.03008511,  64961.38805129, 100419.42884621,
#        108042.42043014, 107870.79053328,  62837.16430472,  63478.851108  ,
#         38597.49101136,  82781.30772753,  70861.60270482,  67727.94613106,
#         52565.31839815, 102634.62100306,  65742.23999184,  60557.31118318,
# ...

# %% [markdown]
# # Step2: Creating a DataFrame

# %%
data = pd.DataFrame({
    'Size': house_sizes,
    'Price': house_prices
})
data
# Out:
#     Size          Price
# 0   1184   63253.977840
# 1   1059   54136.065852
# 2   2153  120194.140683
# 3   1716   99991.020408
# 4   1335   59311.439171
# ..   ...            ...
# 95  2089  119508.383628
# 96  1408   71445.209233
# 97  1133   54289.568494
# 98  2462  131294.350339
# 99   584   33228.564387
#
# [100 rows x 2 columns]

# %% [markdown]
# # Step3: Split the dataset into training and testing sets

# %%
X = data[['Size']] #Features (independent variable)
y = data[['Price']] #Target (dependent variable)

# Separating 80% of data for training and 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Step 4: Build and train Linear Regression Model

# %%
model = LinearRegression() #Create an instance of LinearRegression
model.fit(X_train, y_train) # Train the model
LinearRegression()
# Out:
# LinearRegression()

# %% [markdown]
# # Step5: Make predictions on the test set

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[108397.55661358],
#        [117959.19242535],
#        [106019.53319926],
#        [ 59499.45015654],
#        [ 43348.70780092],
#        [ 43844.12934558],
#        [ 53851.64454752],
#        [ 37651.36003744],
#        [ 51027.74174301],
#        [102848.83531349],
#        [ 51077.28389748],
#        [119247.28844144],
#        [ 96755.15031429],
#        [ 53802.10239306],
#        [ 92643.15149369],
#        [ 62620.60588784],
#        [ 28436.51930693],
#        [104582.81071977],
#        [ 72479.4946264 ],
#        [ 75303.39743091]])

# %% [markdown]
# # Step6: Visualize the results

# %%
plt.figure(figsize=(10,6))
# Plot training data
plt.scatter(X_train, y_train, color='blue', label='Training Data')
# Plotting testing data
plt.scatter(X_test, y_test, color='green', label='Testing Data')
# Plot regression line
plt.plot(X_test, predictions, color ='red', linewidth=2, label='Regression Line')

# Adding labels and titles
plt.title('House Price Predictions')
plt.xlabel('Size(Square Feet)')
plt.ylabel('Price($)')
plt.legend()
plt.grid()

# Show the plot
plt.show()
